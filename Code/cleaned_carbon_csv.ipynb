# %%
import pandas as pd

# %%
carbon_df = pd.read_csv('owid-co2-data.csv')

# %%
carbon_df
# Out:
#       iso_code      country  year     co2  consumption_co2  co2_growth_prct  \
# 0          AFG  Afghanistan  1949   0.015              NaN              NaN
# 1          AFG  Afghanistan  1950   0.084              NaN           475.00
# 2          AFG  Afghanistan  1951   0.092              NaN             8.70
# 3          AFG  Afghanistan  1952   0.092              NaN             0.00
# 4          AFG  Afghanistan  1953   0.106              NaN            16.00
# ...        ...          ...   ...     ...              ...              ...
# 25199      ZWE     Zimbabwe  2016  10.738           12.153           -12.17
# 25200      ZWE     Zimbabwe  2017   9.582           11.248           -10.77
# 25201      ZWE     Zimbabwe  2018  11.854           13.163            23.72
# 25202      ZWE     Zimbabwe  2019  10.949           12.422            -7.64
# 25203      ZWE     Zimbabwe  2020  10.531              NaN            -3.82
#
# ...

# %%
carbon_df.dtypes
# Out:
# iso_code                                object
# country                                 object
# year                                     int64
# co2                                    float64
# consumption_co2                        float64
# co2_growth_prct                        float64
# co2_growth_abs                         float64
# trade_co2                              float64
# co2_per_capita                         float64
# consumption_co2_per_capita             float64
# share_global_co2                       float64
# cumulative_co2                         float64
# share_global_cumulative_co2            float64
# co2_per_gdp                            float64
# consumption_co2_per_gdp                float64
# co2_per_unit_energy                    float64
# coal_co2                               float64
# cement_co2                             float64
# flaring_co2                            float64
# gas_co2                                float64
# ...

# %%
# remove NaNs

carbon2_df = carbon_df.dropna()

# %%
carbon2_df
# Out:
#        iso_code        country  year        co2  consumption_co2  \
# 1565        AUS      Australia  1990    279.365          245.907
# 1566        AUS      Australia  1991    281.872          247.517
# 1567        AUS      Australia  1992    286.332          249.781
# 1568        AUS      Australia  1993    291.325          251.300
# 1569        AUS      Australia  1994    300.084          262.619
# ...         ...            ...   ...        ...              ...
# 24063       USA  United States  2016   5248.024         5576.720
# 24913  OWID_WRL          World  1990  22749.574        22749.574
# 24923  OWID_WRL          World  2000  25234.207        25234.207
# 24933  OWID_WRL          World  2010  33343.300        33343.300
# 24939  OWID_WRL          World  2016  35452.459        35452.459
#
#        co2_growth_prct  co2_growth_abs  trade_co2  co2_per_capita  \
# 1565              0.67           1.864    -33.458          16.471
# ...

# %%
# dropping columns not needed
carbon_focus_df = carbon2_df.drop(columns=['ghg_per_capita', 'methane', 'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita', 'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita', 
                                           'energy_per_gdp', 'total_ghg'])

# %%
carbon_focus_df.head(20)
# Out:
#      iso_code    country  year      co2  consumption_co2  co2_growth_prct  \
# 1565      AUS  Australia  1990  279.365          245.907             0.67
# 1566      AUS  Australia  1991  281.872          247.517             0.90
# 1567      AUS  Australia  1992  286.332          249.781             1.58
# 1568      AUS  Australia  1993  291.325          251.300             1.74
# 1569      AUS  Australia  1994  300.084          262.619             3.01
# 1570      AUS  Australia  1995  308.023          265.935             2.65
# 1571      AUS  Australia  1996  316.332          273.242             2.70
# 1572      AUS  Australia  1997  327.110          282.701             3.41
# 1573      AUS  Australia  1998  338.697          300.016             3.54
# 1574      AUS  Australia  1999  346.599          298.021             2.33
# 1575      AUS  Australia  2000  351.820          291.343             1.51
# 1576      AUS  Australia  2001  360.455          298.181             2.45
# ...

# %%
# Saving cleaned data
file_path = "carbon_data_cleaned.csv"
carbon_focus_df.to_csv(file_path, index=False)
