# %%
import pandas as pd
import os

# %%
directory = "Severe Weather Event Data\details"
appended_data = []

for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        full_filename = (os.path.join(directory, filename))
        df = pd.read_csv(full_filename)
        df2 = df.drop(['BEGIN_YEARMONTH',
            'BEGIN_DAY',
            'BEGIN_TIME',
            'END_YEARMONTH',
            'END_DAY',
            'END_TIME',
            'EPISODE_ID',
            'CZ_TYPE',
            'CZ_FIPS',
            'CZ_NAME',
            'WFO',
            'BEGIN_DATE_TIME',
            'CZ_TIMEZONE',
            'END_DATE_TIME',
            'SOURCE',
            'MAGNITUDE_TYPE',
            'FLOOD_CAUSE',
            'TOR_OTHER_WFO',
            'TOR_OTHER_CZ_STATE',
            'TOR_OTHER_CZ_FIPS',
            'TOR_OTHER_CZ_NAME',
            'BEGIN_RANGE',
            'BEGIN_AZIMUTH',
            'BEGIN_LOCATION',
            'END_RANGE',
            'END_AZIMUTH',
            'END_LOCATION',
            'END_LAT',
            'END_LON',
            'EPISODE_NARRATIVE',
            'EVENT_NARRATIVE',
            'DATA_SOURCE'], axis=1)
        # store DataFrame in list
        appended_data.append(df2)
        continue
    else:
        continue
appended_data = pd.concat(appended_data)
appended_data.to_csv(os.path.join(directory,'SevereWeatherDetails_appended.csv'), index=False)

# %%
print(appended_data.shape)
appended_data.head(20)
# Out:
# (1702313, 19)
#     EVENT_ID         STATE  STATE_FIPS  YEAR MONTH_NAME EVENT_TYPE  \
# 0   10096222      OKLAHOMA        40.0  1950      April    Tornado
# 1   10120412         TEXAS        48.0  1950      April    Tornado
# 2   10104927  PENNSYLVANIA        42.0  1950       July    Tornado
# 3   10104928  PENNSYLVANIA        42.0  1950       July    Tornado
# 4   10104929  PENNSYLVANIA        42.0  1950       July    Tornado
# 5   10104930  PENNSYLVANIA        42.0  1950     August    Tornado
# 6   10104931  PENNSYLVANIA        42.0  1950   November    Tornado
# 7   10104932  PENNSYLVANIA        42.0  1950   November    Tornado
# 8   10099490      OKLAHOMA        40.0  1950  September    Tornado
# 9   10099491      OKLAHOMA        40.0  1950  September    Tornado
# 10  10099492      OKLAHOMA        40.0  1950    October    Tornado
# 11  10073785      NEBRASKA        31.0  1950       June    Tornado
# 12  10096216      OKLAHOMA        40.0  1950   February    Tornado
# ...
